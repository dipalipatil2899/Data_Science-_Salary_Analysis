# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Data science salaries.csv')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.094724       0.228290     -0.236430
# salary         -0.094724  1.000000      -0.023676      0.028731
# salary_in_usd   0.228290 -0.023676       1.000000     -0.064171
# remote_ratio   -0.236430  0.028731      -0.064171      1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  3755.000000  3.755000e+03    3755.000000   3755.000000
# mean   2022.373635  1.906956e+05  137570.389880     46.271638
# std       0.691448  6.716765e+05   63055.625278     48.589050
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   95000.000000      0.000000
# 50%    2022.000000  1.380000e+05  135000.000000      0.000000
# 75%    2023.000000  1.800000e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
# %matplotlib inline
sns.set(style="darkgrid")

# %%
sns.distplot(df['remote_ratio'])
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='Density'>

# %%
sns.distplot(df['remote_ratio'],kde=False,bins=20)
# Out:
# <AxesSubplot:xlabel='remote_ratio'>

# %%
sns.jointplot(x='remote_ratio',y='salary',data=df,kind='scatter')

# %%
sns.jointplot(x='remote_ratio',y='work_year',data=df,kind='hex')

# %%
sns.jointplot(x='work_year',y='remote_ratio',data=df,kind='reg')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='remote_ratio',palette='coolwarm')

# %%
sns.kdeplot(df['remote_ratio'])
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='Density'>

# %%
sns.kdeplot(df['work_year'])
# Out:
# <AxesSubplot:xlabel='work_year', ylabel='Density'>

# %%
sns.barplot(x='salary_currency',y='remote_ratio',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='salary_currency',y='remote_ratio',data=df,estimator=np.std)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='remote_ratio',data=df)
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='count'>

# %%
sns.boxplot(x='salary_currency',y='remote_ratio',data=df,palette='rainbow')
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data=df,palette='rainbow',orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='salary_currency',y='remote_ratio',hue='employment_type',data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='salary_currency', ylabel='remote_ratio'>

# %%
sns.violinplot(x='employment_type',y='remote_ratio',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='employment_type', ylabel='remote_ratio'>

# %%
sns.violinplot(x='employment_type',y='remote_ratio',data=df,hue='work_year',palette='rainbow')
# Out:
# <AxesSubplot:xlabel='employment_type', ylabel='remote_ratio'>

# %%
sns.stripplot(x='remote_ratio',y='employment_type',data=df,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='employment_type'>

# %%
sns.stripplot(x='remote_ratio',y='employment_type',data=df,palette='rainbow',hue='work_year',jitter=True)
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='employment_type'>

# %%
sns.stripplot(x='remote_ratio',y='employment_type',data=df,palette='Set1',hue='work_year',jitter=True)
# Out:
# <AxesSubplot:xlabel='remote_ratio', ylabel='employment_type'>

# %%
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
pv=df.pivot_table(values='remote_ratio',index='work_year',columns='employment_type')
pv
# Out:
# employment_type     CT          FL         FT          PT
# work_year
# 2020             100.0  100.000000  63.888889   75.000000
# 2021             100.0   33.333333  68.663594   71.428571
# 2022              87.5  100.000000  55.124318   78.571429
# 2023             100.0   50.000000  33.932584  100.000000

# %%
pvdf=df.pivot_table(values='remote_ratio',index='work_year',columns='employment_type')
sns.heatmap(pvdf)
# Out:
# <AxesSubplot:xlabel='employment_type', ylabel='work_year'>

# %%
sns.heatmap(pvdf,cmap='magma',linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:xlabel='employment_type', ylabel='work_year'>

# %%
sns.clustermap(pvdf)

# %%
sns.clustermap(pvdf,cmap='coolwarm',standard_scale=1)

# %%
s = sns.PairGrid(df)
s.map(plt.scatter)

# %%
s = sns.PairGrid(df)
s.map_diag(plt.hist)
s.map_upper(plt.scatter)
s.map_lower(sns.kdeplot,color='green')

# %%
sns.pairplot(df,hue='work_year',palette='rainbow')

# %%
g = sns.FacetGrid(df,col='work_year')
g = g.map(plt.hist,'remote_ratio')

# %%
a=sns.FacetGrid(df,col='employment_type',hue='work_year')
a=a.map(plt.scatter,'remote_ratio','salary_currency')

# %%
b = sns.JointGrid(x='remote_ratio',y='work_year',data=df)
b = b.plot(sns.regplot, sns.distplot)

# %%
sns.lmplot(x='salary',y='salary_in_usd',data=df)

# %%
sns.lmplot(x='salary',y='salary_in_usd',data=df,hue='work_year')

# %%
sns.lmplot(x='salary',y='salary_in_usd',data=df,hue='work_year',palette='coolwarm')

# %%
sns.lmplot(x='salary',y='salary_in_usd',data=df,hue='work_year',palette='coolwarm',scatter_kws={'s':100})

# %%
sns.lmplot(x='salary',y='salary_in_usd',data=df,col='remote_ratio')

# %%
sns.lmplot(x='salary',y='salary_in_usd',row='remote_ratio',data=df)

# %%
sns.lmplot(x='salary',y='salary_in_usd',row='remote_ratio',data=df,hue='work_year',palette='coolwarm')

# %%
sns.lmplot(x='salary',y='salary_in_usd',row='remote_ratio',data=df,hue='work_year',palette='coolwarm',aspect=1.2)

# %% [markdown]
# ### Thank You !
